# %%
URL1="https://nl.wikipedia.org/wiki/Provinciale_Statenverkiezingen_2023"
URL2="https://nl.wikipedia.org/wiki/Provinciale_Statenverkiezingen_2019"

# %%
import requests
from bs4 import BeautifulSoup
import pickle
from bs4.element import Comment
import urllib.request
import httplib2
import re
import itertools

# %%
http = httplib2.Http()
status, response = http.request(URL1)
soup=BeautifulSoup(response)
#print(soup.prettify())
My_table = soup.find_all('table',{'class':'wikitable'})
Election=My_table[1]
Links=Election.findAll('a')
Parties=[]
for i in range(0,15):
  Parties.append(Links[i].get('title'))
Parties.append("DENK") #Not in 2023
Parties
# Out:
# ['BoerBurgerBeweging',
#  'Volkspartij voor Vrijheid en Democratie',
#  'GroenLinks',
#  'Partij van de Arbeid (Nederland)',
#  'Christen-Democratisch Appèl',
#  'Partij voor de Vrijheid',
#  'Democraten 66',
#  'Partij voor de Dieren',
#  'Socialistische Partij (Nederland)',
#  'JA21',
#  'ChristenUnie',
#  'Staatkundig Gereformeerde Partij',
#  'Forum voor Democratie',
#  'Volt Nederland',
#  '50PLUS',
#  'DENK']

# %%
#print(Election)
Groningen=[]
Friesland=[]
Drenthe=[]
Overijssel=[]
Flevoland=[]
Gelderland=[]
Utrecht=[]
Noord_Holland=[]
Zuid_Holland=[]
Zeeland=[]
Noord_Brabant=[]
Limburg=[]
Numbers=Election.findAll('td')
#Horribly Inefficient
for i in range(1,16):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Groningen.append(k)
print("FRIESLAND")
for i in range(19,34):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Friesland.append(k)
print("DRENTHE")
for i in range(37,52):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Drenthe.append(k)
print("OVERIJSSEL")
for i in range(55,70):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Overijssel.append(k)
print("FLEVOLAND")
for i in range(73,88):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Flevoland.append(k)
print("GELDERLAND")
for i in range(91,106):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Gelderland.append(k)
print("UTRECHT")
for i in range(109,124):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Utrecht.append(k)
print("NOORD-HOLLAND")
for i in range(127,142):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Noord_Holland.append(k)
print("ZUID-HOLLAND")
for i in range(145,160):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Zuid_Holland.append(k)
print("ZEELAND")
for i in range(163,177):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  try:
    k=int(k)
    Zeeland.append(k)
  except:
    if k =="-":
      Zeeland.append(k)
    else:
      l=re.sub(r"(?<=(\<|\[)).+?(?=(\>|\]))",r"",k)
      m=re.sub(r"\<|\>|\[|\]",r"",l)
      m=int(m)
      Zeeland.append(m/2)
      Zeeland.append(m/2)
print("NOORD-BRABANT")
for i in range(180,194):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  try:
    k=int(k)
    Noord_Brabant.append(k)
  except:
    if k =="-":
      Noord_Brabant.append(k)
    else:
      l=re.sub(r"(?<=(\<|\[)).+?(?=(\>|\]))",r"",k)
      m=re.sub(r"\<|\>|\[|\]",r"",l)
      m=int(m)
      Noord_Brabant.append(m/2)
      Noord_Brabant.append(m/2)
print("LIMBURG")
for i in range(197,212):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Limburg.append(k)
# Out:
# FRIESLAND
# DRENTHE
# OVERIJSSEL
# FLEVOLAND
# GELDERLAND
# UTRECHT
# NOORD-HOLLAND
# ZUID-HOLLAND
# ZEELAND
# NOORD-BRABANT
# LIMBURG

# %%
ListofProvinces=[Groningen,Friesland,Drenthe,Overijssel,Flevoland,Gelderland,Utrecht,Noord_Holland,Zuid_Holland,Zeeland,Noord_Brabant,Limburg]
for i in ListofProvinces:
  i.append(0)
  print(len(i))
# Out:
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16

# %%
http = httplib2.Http()
status, response = http.request(URL2)
soup=BeautifulSoup(response)
#print(soup.prettify())
My_table = soup.find_all('table',{'class':'wikitable'})
Election=My_table[1]
Links=Election.findAll('a')

# %%
Groningen2019=[0,0,0]
Friesland2019=[0,0,0]
Drenthe2019=[0,0,0]
Overijssel2019=[0,0,0]
Flevoland2019=[0,0,0]
Gelderland2019=[0,0,0]
Utrecht2019=[0,0,0]
Noord_Holland2019=[0,0,0]
Zuid_Holland2019=[0,0,0]
Zeeland2019=[0,0,0]
Noord_Brabant2019=[0,0,0]
Limburg2019=[0,0,0]
Numbers=Election.findAll('td')
print("GRONINGEN")
for i in range(1,14):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Groningen2019.append(k)
print("FRIESLAND")
for i in range(17,30):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Friesland2019.append(k)
print("DRENTHE")
for i in range(33,46):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Drenthe2019.append(k)
print("OVERIJSSEL")
for i in range(49,62):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Overijssel2019.append(k)
print("FLEVOLAND")
for i in range(65,78):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Flevoland2019.append(k)
print("GELDERLAND")
for i in range(81,94):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Gelderland2019.append(k)
print("UTRECHT")
for i in range(97,110):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Utrecht2019.append(k)
print("NOORD-HOLLAND")
for i in range(113,126):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  l=re.sub(r"(?<=(\<|\[)).+?(?=(\>|\]))",r"",k)
  m=re.sub(r"\<|\>|\[|\]",r"",l)
  #print(k)
  Noord_Holland2019.append(m)
print("ZUID-HOLLAND")
for i in range(129,142):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Zuid_Holland2019.append(k)
print("ZEELAND")
for i in range(145,158):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  try:
    k=int(k)
    Zeeland2019.append(k)
  except:
    if k =="-":
      Zeeland2019.append(k)
    else:
      l=re.sub(r"(?<=(\<|\[)).+?(?=(\>|\]))",r"",k)
      m=re.sub(r"\<|\>|\[|\]",r"",l)
      m=int(m)
      Zeeland2019.append(m/2)
      Zeeland2019.append(m/2)
print("NOORD-BRABANT")
for i in range(163,173): #Incorrect range
  print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  try:
    k=int(k)
    Noord_Brabant2019.append(k)
  except:
    if k =="-":
      Noord_Brabant2019.append(k)
    else:
      l=re.sub(r"(?<=(\<|\[)).+?(?=(\>|\]))",r"",k)
      m=re.sub(r"\<|\>|\[|\]",r"",l)
      m=int(m)
      Noord_Brabant2019.append(m/2)
      Noord_Brabant2019.append(m/2)
print("LIMBURG")
for i in range(176,189):
  #print(Numbers[i])
  Numbers[i]=str(Numbers[i])
  j= re.sub(r"\<td\>",r"",Numbers[i])
  k=re.sub(r"\<\/td\>",r"",j)
  #print(k)
  Limburg2019.append(k)
# Out:
# GRONINGEN
# FRIESLAND
# DRENTHE
# OVERIJSSEL
# FLEVOLAND
# GELDERLAND
# UTRECHT
# NOORD-HOLLAND
# ZUID-HOLLAND
# ZEELAND
# NOORD-BRABANT
# <td>9</td>
# <td>4</td>
# <td colspan="2">6<sup class="reference" id="cite_ref-GL/PvdA_10-0"><a href="#cite_note-GL/PvdA-10">[10]</a></sup></td>
# <td>5</td>
# <td>2</td>
# <td>1</td>
# <td>1</td>
# <td>1</td>
# <td>1</td>
# <td>1</td>
# LIMBURG

# %%
ListofProvinces2019=[Groningen2019,Friesland2019,Drenthe2019,Overijssel2019,Flevoland2019,Gelderland2019,Utrecht2019,Noord_Holland2019,Zuid_Holland2019,Zeeland2019,Noord_Brabant2019,Limburg2019]
for i in ListofProvinces2019:
  print(len(i))
  print(i)
# Out:
# 16
# [0, 0, 0, '5', '4', '3', '6', '5', '3', '2', '4', '4', '-', '1', '1', '0']
# 16
# [0, 0, 0, '6', '4', '8', '3', '6', '2', '3', '2', '3', '0', '1', '1', '0']
# 16
# [0, 0, 0, '6', '6', '5', '4', '6', '2', '3', '3', '3', '0', '1', '1', '0']
# 16
# [0, 0, 0, '6', '6', '9', '5', '4', '3', '3', '3', '4', '2', '1', '1', '0']
# 16
# [0, 0, 0, '8', '6', '3', '4', '3', '2', '4', '2', '3', '1', '2', '2', '1']
# 16
# [0, 0, 0, '8', '8', '7', '6', '5', '4', '3', '3', '4', '3', '2', '2', '0']
# 16
# [0, 0, 0, '6', '8', '5', '8', '4', '5', '2', '2', '4', '1', '2', '1', '1']
# 16
# [0, 0, 0, '9', '9', '4', '9', '6', '6', '3', '3', '1', '-', '3', '1', '1']
# 16
# [0, 0, 0, '11', '10', '4', '5', '4', '5', '4', '2', '3', '2', '2', '2', '1']
# 16
# [0, 0, 0, 5, 4, 7, 2, 4, 1, 2, 2, 2, 5, 1, 2, 0]
# 16
# [0, 0, 0, 9, 10, 8, 5, 3, 5, 4, 5, 0.5, 0.5, 2, 2, 0]
# 16
# [0, 0, 0, '7', '5', '9', '4', '3', '3', '7', '4', '0', '-', '2', '1', '0']

# %%
Parties2019=['BoerBurgerBeweging', 'Volt Nederland', 'JA21','Forum voor Democratie','Volkspartij voor Vrijheid en Democratie','Christen-Democratisch Appèl','GroenLinks','Partij van de Arbeid (Nederland)','Democraten 66',
             'Partij voor de Vrijheid','Socialistische Partij (Nederland)','ChristenUnie','Staatkundig Gereformeerde Partij','Partij voor de Dieren','50PLUS','DENK']
for i, j,k in zip(Parties,Parties2019,enumerate(Parties2019)):
  print(i,"2023",j,"2019",k)
print(len(Parties),len(Parties2019))
'''
0 matches 0
1 matches 4
2 matches 6
3 matches 7
4 matches 5
5 matches 9
6 matches 8
7 matches 13
8 matches 10
9 matches 2
10 matches 11
11 matches 12
12 matches 3
13 matches 1
14 matches 14
15 matches 15
'''
# Out:
# BoerBurgerBeweging 2023 BoerBurgerBeweging 2019 (0, 'BoerBurgerBeweging')
# Volkspartij voor Vrijheid en Democratie 2023 Volt Nederland 2019 (1, 'Volt Nederland')
# GroenLinks 2023 JA21 2019 (2, 'JA21')
# Partij van de Arbeid (Nederland) 2023 Forum voor Democratie 2019 (3, 'Forum voor Democratie')
# Christen-Democratisch Appèl 2023 Volkspartij voor Vrijheid en Democratie 2019 (4, 'Volkspartij voor Vrijheid en Democratie')
# Partij voor de Vrijheid 2023 Christen-Democratisch Appèl 2019 (5, 'Christen-Democratisch Appèl')
# Democraten 66 2023 GroenLinks 2019 (6, 'GroenLinks')
# Partij voor de Dieren 2023 Partij van de Arbeid (Nederland) 2019 (7, 'Partij van de Arbeid (Nederland)')
# Socialistische Partij (Nederland) 2023 Democraten 66 2019 (8, 'Democraten 66')
# JA21 2023 Partij voor de Vrijheid 2019 (9, 'Partij voor de Vrijheid')
# ChristenUnie 2023 Socialistische Partij (Nederland) 2019 (10, 'Socialistische Partij (Nederland)')
# ...

# %%
Groningen2019Unshuffled=[]
Friesland2019Unshuffled=[]
Drenthe2019Unshuffled=[]
Overijssel2019Unshuffled=[]
Flevoland2019Unshuffled=[]
Gelderland2019Unshuffled=[]
Utrecht2019Unshuffled=[]
Noord_Holland2019Unshuffled=[]
Zuid_Holland2019Unshuffled=[]
Zeeland2019Unshuffled=[]
Noord_Brabant2019Unshuffled=[]
Limburg2019Unshuffled=[]
ListOfUnshuffled=[Groningen2019Unshuffled,Friesland2019Unshuffled,Drenthe2019Unshuffled,Overijssel2019Unshuffled,Flevoland2019Unshuffled,Gelderland2019Unshuffled,Utrecht2019Unshuffled,
                  Noord_Holland2019Unshuffled,Zuid_Holland2019Unshuffled,Zeeland2019Unshuffled,Noord_Brabant2019Unshuffled,Limburg2019Unshuffled]
for i,j in zip(ListofProvinces2019,ListOfUnshuffled):
  print(len(i),len(j))
  j.append(i[0])
  j.append(i[4])
  j.append(i[6])
  j.append(i[7])
  j.append(i[5])
  j.append(i[9])
  j.append(i[8])
  j.append(i[13])
  j.append(i[10])
  j.append(i[2])
  j.append(i[11])
  j.append(i[12])
  j.append(i[3])
  j.append(i[1])
  j.append(i[14])
  j.append(i[15])
# Out:
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0
# 16 0

# %%
GroningenDiff=[]
FrieslandDiff=[]
DrentheDiff=[]
OverijsselDiff=[]
FlevolandDiff=[]
GelderlandDiff=[]
UtrechtDiff=[]
Noord_HollandDiff=[]
Zuid_HollandDiff=[]
ZeelandDiff=[]
Noord_BrabantDiff=[]
LimburgDiff=[]
ListofDiff=[GroningenDiff,FrieslandDiff,DrentheDiff,OverijsselDiff,FlevolandDiff,GelderlandDiff,UtrechtDiff,Noord_HollandDiff,Zuid_HollandDiff,ZeelandDiff,Noord_BrabantDiff,LimburgDiff]

# %%
for i,j,k in zip(ListofProvinces,ListOfUnshuffled,ListofDiff):
  print(i,j)
  TempList=[]
  for a,b in zip(i,j):
    try:
      a=int(a)
      b=int(b)
      TempList.append(a-b)
    except:
      TempList.append("NA")
  k.append(TempList)
print(len(ListofDiff))
for i in ListofDiff:
  print(len(i))
# Out:
# ['12', '2', '5', '5', '2', '2', '2', '2', '2', '0', '3', '0', '1', '1', '0', 0] [0, '4', '6', '5', '3', '2', '3', '1', '4', 0, '4', '-', '5', 0, '1', '0']
# ['14', '3', '3', '5', '4', '2', '1', '1', '1', '1', '2', '-', '1', '-', '0', 0] [0, '4', '3', '6', '8', '3', '2', '1', '2', 0, '3', '0', '6', 0, '1', '0']
# ['17', '4', '2', '4', '3', '2', '1', '2', '2', '1', '2', '0', '1', '1', '0', 0] [0, '6', '4', '6', '5', '3', '2', '1', '3', 0, '3', '0', '6', 0, '1', '0']
# ['17', '4', '4', '3', '4', '2', '2', '1', '1', '2', '3', '2', '1', '1', '0', 0] [0, '6', '5', '4', '9', '3', '3', '1', '3', 0, '4', '2', '6', 0, '1', '0']
# ['10', '4', '3', '3', '2', '3', '2', '2', '2', '2', '2', '2', '2', '-', '1', 0] [0, '6', '4', '3', '3', '4', '2', '2', '2', 0, '3', '1', '8', 0, '2', '1']
# ['14', '6', '5', '5', '4', '2', '3', '2', '2', '2', '3', '3', '1', '2', '1', 0] [0, '8', '6', '5', '7', '3', '4', '2', '3', 0, '4', '3', '8', 0, '2', '0']
# ...

# %%
print(ListofDiff[0][0])
# Out:
# [12, -2, -1, 0, -1, 0, -1, 1, -2, 0, -1, 'NA', -4, 1, -1, 0]

# %%
Parties2023=['BoerBurgerBeweging(2023)',
 'Volkspartij voor Vrijheid en Democratie(2023)',
 'GroenLinks(2023)',
 'Partij van de Arbeid (Nederland)(2023)',
 'Christen-Democratisch Appèl(2023)',
 'Partij voor de Vrijheid(2023)',
 'Democraten 66(2023)',
 'Partij voor de Dieren(2023)',
 'Socialistische Partij (Nederland)(2023)',
 'JA21(2023)',
 'ChristenUnie(2023)',
 'Staatkundig Gereformeerde Partij(2023)',
 'Forum voor Democratie(2023)',
 'Volt Nederland(2023)',
 '50PLUS(2023)',
 'DENK(2023)']
Parties2019=['BoerBurgerBeweging(2019)',
 'Volkspartij voor Vrijheid en Democratie(2019)',
 'GroenLinks(2019)',
 'Partij van de Arbeid (Nederland)(2019)',
 'Christen-Democratisch Appèl(2019)',
 'Partij voor de Vrijheid(2019)',
 'Democraten 66(2019)',
 'Partij voor de Dieren(2019)',
 'Socialistische Partij (Nederland)(2019)',
 'JA21(2019)',
 'ChristenUnie(2019)',
 'Staatkundig Gereformeerde Partij(2019)',
 'Forum voor Democratie(2019)',
 'Volt Nederland(2019)',
 '50PLUS(2019)',
 'DENK(2019)']
PartiesDiff=['BoerBurgerBeweging(DIFF)',
 'Volkspartij voor Vrijheid en Democratie(DIFF)',
 'GroenLinks(DIFF)',
 'Partij van de Arbeid (Nederland)(DIFF)',
 'Christen-Democratisch Appèl(DIFF)',
 'Partij voor de Vrijheid(DIFF)',
 'Democraten 66(DIFF)',
 'Partij voor de Dieren(DIFF)',
 'Socialistische Partij (Nederland)(DIFF)',
 'JA21(DIFF)',
 'ChristenUnie(DIFF)',
 'Staatkundig Gereformeerde Partij(DIFF)',
 'Forum voor Democratie(DIFF)',
 'Volt Nederland(DIFF)',
 '50PLUS(DIFF)',
 'DENK(DIFF)']
Prov2023=["Groningen2023","Friesland2023","Drenthe2023",
          "Overijssel2023","Flevoland2023","Gelderland2023",
          "Utrecht2023","Noord-Holland2023","Zuid-Holland2023",
          "Zeeland2023","Noord-Brabant2023","Limburg2023"]
Prov2019=["Groningen2019","Friesland2019","Drenthe2019",
          "Overijssel2019","Flevoland2019","Gelderland2019",
          "Utrecht2019","Noord-Holland2019","Zuid-Holland2019",
          "Zeeland2019","Noord-Brabant2019","Limburg2019"]
ProvDiff=["GroningenDiff","FrieslandDiff","DrentheDiff",
          "OverijsselDiff","FlevolandDiff","GelderlandDiff",
          "UtrechtDiff","Noord-HollandDiff","Zuid-HollandDiff",
          "ZeelandDiff","Noord-BrabantDiff","LimburgDiff"]

# %%
Results=[]
Labels=[]
Provincials=[]
print(len(ListofProvinces))
for i,j,k in zip(ListofProvinces,ListOfUnshuffled,ListofDiff):
  print(len(i),len(j),len(k[0]))
  Results.append(i);Results.append(j);Results.append(k[0])
  print(len(Results))
for i,j,k in zip(Parties2023,Parties2019,PartiesDiff):
  Labels.append(i);Labels.append(j);Labels.append(k)
for i,j,k in zip(Prov2023,Prov2019,ProvDiff):
  Provincials.append(i);Provincials.append(j);Provincials.append(k)
# Out:
# 12
# 16 16 16
# 3
# 16 16 16
# 6
# 16 16 16
# 9
# 16 16 16
# 12
# 16 16 16
# 15
# 16 16 16
# 18
# 16 16 16
# 21
# 16 16 16
# 24
# 16 16 16
# 27
# 16 16 16
# 30
# 16 16 16
# 33
# 16 16 16
# 36

# %%
print(len(Results),len(Labels),len(Provincials))
for i in Results:
  print(len(i))
print(Results)
# Out:
# 36 48 36
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# ...

# %%
import pandas as pd
df = pd.DataFrame(Results,columns=Parties,index=Provincials)
dg=df.T
print(dg.head())
# Out:
#                                         Groningen2023 Groningen2019  \
# BoerBurgerBeweging                                 12             0
# Volkspartij voor Vrijheid en Democratie             2             4
# GroenLinks                                          5             6
# Partij van de Arbeid (Nederland)                    5             5
# Christen-Democratisch Appèl                         2             3
#
#                                         GroningenDiff Friesland2023  \
# BoerBurgerBeweging                                 12            14
# Volkspartij voor Vrijheid en Democratie            -2             3
# GroenLinks                                         -1             3
# Partij van de Arbeid (Nederland)                    0             5
# Christen-Democratisch Appèl                        -1             4
#
#                                         Friesland2019 FrieslandDiff  \
# BoerBurgerBeweging                                  0            14
# ...

# %%
# !pip install geopandas
import geopandas as gpd
fp = "DIR/NLD_adm/NLD_adm1.shp"
gdf = gpd.read_file(fp)[['ISO', 'NAME_1', 'geometry']]
gdf.columns = ['code', 'city', 'geometry']
gdf.head()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 29.7 MB/s eta 0:00:00
# ...
#   code        city                                           geometry
# 0  NLD     Drenthe  POLYGON ((6.50131 53.19841, 6.50429 53.19749, ...
# 1  NLD   Flevoland  MULTIPOLYGON (((5.44521 52.55581, 5.43211 52.5...
# 2  NLD   Friesland  MULTIPOLYGON (((5.24917 53.25458, 5.24917 53.2...
# 3  NLD  Gelderland  POLYGON ((5.92733 52.48264, 5.93285 52.47410, ...
# 4  NLD   Groningen  MULTIPOLYGON (((6.75250 53.46569, 6.75250 53.4...

# %%
#print(df.head())
import matplotlib.pyplot as plt
Provies=["Groningen","Friesland","Drenthe",
          "Overijssel","Flevoland","Gelderland",
          "Utrecht","Noord-Holland","Zuid-Holland",
          "Zeeland","Noord-Brabant","Limburg"]
dfs=["df1","df2","df3","df4","df5","df6","df7","df8",
     "df9","df10","df11","df12","df13","df14","df15","df16"]
Boer=[];VVD=[];Groen=[];PvdA=[];CDA=[];PVV=[]
D66=[];PvdD=[];SP=[];JA21=[];CU=[];SGP=[];FVD=[]
Volt=[];FIFTYPLUS=[];DENK=[]
PARTIES=[Boer,VVD,Groen,PvdA,CDA,PVV,D66,PvdD,SP,JA21,CU,SGP,FVD,Volt,FIFTYPLUS,DENK]
for i in ListofDiff:
  Boer.append(i[0][0]);VVD.append(i[0][1]);Groen.append(i[0][2])
  PvdA.append(i[0][3]);CDA.append(i[0][4]);PVV.append(i[0][5])
  D66.append(i[0][6]);PvdD.append(i[0][7]);SP.append(i[0][8])
  JA21.append(i[0][9]);CU.append(i[0][10]);SGP.append(i[0][11])
  FVD.append(i[0][12]);Volt.append(i[0][13]);FIFTYPLUS.append(i[0][14])
  DENK.append(i[0][15])
for i,j,k,l in zip(PARTIES,Provies,dfs,Parties):
  k=pd.DataFrame(list(zip(i,Provies)),columns=['Difference','city'])
  merged = gdf.merge(k, on='city')
  merged.fillna('No data', inplace = True)
  fig, ax = plt.subplots(figsize=(12, 10))
  ax.set_title(l)
  merged.plot(column='Difference', legend=True, ax=ax,edgecolor='0.1',missing_kwds={'color': 'lightgrey'},
              vmin=-5,vmax=17,cmap='RdBu')
  String=l+".png"
  plt.savefig(String)
